# %%
from baselines.common.vec_env import VecEnvWrapper, SubprocVecEnv
from pred_learn.envs import *
from a2c_ppo_acktr.envs import VecPyTorch
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
from a2c_ppo_acktr import algo
from a2c_ppo_acktr.arguments import get_args
from a2c_ppo_acktr.envs import make_vec_envs
from a2c_ppo_acktr.model import Policy
from a2c_ppo_acktr.storage import RolloutStorage
from a2c_ppo_acktr.utils import get_vec_normalize, update_linear_schedule
from a2c_ppo_acktr.visualize import visdom_plot
from collections import deque
import copy
import glob
import os
import time
from collections import deque

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
import torch
# from skimage.transform import resize
import os
import numpy as np

# %%
MAX_STEPS = 500
TOTAL_STEPS = 10000
ENVS = [
    "CarRacing-v0",
    "Snake-ple-v0",
    "TetrisA-v2",
    "PuckWorld-ple-v0",
    "WaterWorld-ple-v0",
    "PixelCopter-ple-v0",
    "CubeCrash-v0",
    "Catcher-ple-v0",
    "Pong-ple-v0",
]
ENV_ID = "PixelCopter-ple-v0"

SEED = 0

# RECORD_DIR = "recorded/{}/".format(ENV_ID)
# FILE_NO = 1


# try:
#     os.makedirs(RECORD_DIR)
# except FileExistsError:
#     pass

# %%
env = make_env(ENV_ID, SEED)
env._env
# Out:
# /home/ira/code/envs/flexi/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Environment '<class 'gym_ple.ple_env.PLEEnv'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class Object(object):
    pass

args = Object()
args.cuda = True
args.vis = False
args.num_processes = 4
args.seed = SEED

args.env_name = ENV_ID

args.gamma = 0.99
args.log_dir = "tests"
args.log_interval = 1
args.eval_interval = 10
eval_log_dir = args.log_dir + "_eval"
args.add_timestep = False
args.add_padding = False
args.recurrent_policy = False
args.algo = "a2c"
args.value_loss_coef = 0.5
args.entropy_coef = 0.01
args.lr = 7e-4
args.eps = 1e-5
args.alpha = 0.99
args.max_grad_norm = 0.5
args.num_steps = 15
args.use_linear_lr_decay = False
args.use_gae = False
args.tau = 0.95
args.clip_param = 0.2
args.ppo_epoch = 4
args.num_mini_batch = 32
args.use_linear_clip_decay = False
args.save_interval = 1000
args.save_dir = "save_dir"

num_updates = 100000

try:
    os.makedirs(args.log_dir)
except OSError:
    files = glob.glob(os.path.join(args.log_dir, '*.monitor.csv'))
    for f in files:
        os.remove(f)
        
try:
    os.makedirs(eval_log_dir)
except OSError:
    files = glob.glob(os.path.join(eval_log_dir, '*.monitor.csv'))
    for f in files:
        os.remove(f)

# %%
torch.set_num_threads(1)
device = torch.device("cuda:0" if args.cuda else "cpu")

if args.vis:
    from visdom import Visdom
    viz = Visdom(port=args.port)
    win = None

envs = make_vec_envs(args.env_name, args.seed, args.num_processes,
                     args.gamma, args.log_dir, args.add_timestep, device, True,
                     padding_type=args.add_padding)

# envs = make_rl_envs(args.env_name, args.num_processes, args.seed, device)
    
actor_critic = Policy(envs.observation_space.shape, envs.action_space,
    base_kwargs={'recurrent': args.recurrent_policy})
actor_critic.to(device)

if args.algo == 'a2c':
    agent = algo.A2C_ACKTR(actor_critic, args.value_loss_coef,
                           args.entropy_coef, lr=args.lr,
                           eps=args.eps, alpha=args.alpha,
                           max_grad_norm=args.max_grad_norm)
elif args.algo == 'ppo':
    agent = algo.PPO(actor_critic, args.clip_param, args.ppo_epoch, args.num_mini_batch,
                     args.value_loss_coef, args.entropy_coef, lr=args.lr,
                           eps=args.eps,
                           max_grad_norm=args.max_grad_norm)
elif args.algo == 'acktr':
    agent = algo.A2C_ACKTR(actor_critic, args.value_loss_coef,
                           args.entropy_coef, acktr=True)

rollouts = RolloutStorage(args.num_steps, args.num_processes,
                    envs.observation_space.shape, envs.action_space,
                    actor_critic.recurrent_hidden_state_size)

# %%
# some_model = torch.load("../../pytorch-a2c-ppo-acktr/trained_models/ppo/CarRacing-v0.pt")
# actor_critic, _ = some_model
# actor_critic = actor_critic.cuda()

# %%
envs = make_vec_envs(args.env_name, args.seed, args.num_processes,
                     args.gamma, args.log_dir, args.add_timestep, device, True,
                     padding_type=args.add_padding)

# envs = make_rl_envs(args.env_name, args.num_processes, args.seed, device)


obs = envs.reset()
rollouts.obs[0].copy_(obs)
rollouts.to(device)

episode_rewards = deque(maxlen=10)

training_stats = {
    'updates': [],
    'num_timesteps': [],
    'mean_reward': [],
    'median_reward': [],
    'min_reward': [],
    'max_reward': []
}

start = time.time()
for j in range(num_updates):

    if args.use_linear_lr_decay:
        # decrease learning rate linearly
        if args.algo == "acktr":
            # use optimizer's learning rate since it's hard-coded in kfac.py
            update_linear_schedule(agent.optimizer, j, num_updates, agent.optimizer.lr)
        else:
            update_linear_schedule(agent.optimizer, j, num_updates, args.lr)

    if args.algo == 'ppo' and args.use_linear_clip_decay:
        agent.clip_param = args.clip_param  * (1 - j / float(num_updates))

    for step in range(args.num_steps):
        # Sample actions
        with torch.no_grad():
            value, action, action_log_prob, recurrent_hidden_states = actor_critic.act(
                    rollouts.obs[step],
                    rollouts.recurrent_hidden_states[step],
                    rollouts.masks[step])

        # Obser reward and next obs
        obs, reward, done, infos = envs.step(action)

        for info in infos:
            if 'episode' in info.keys():
                episode_rewards.append(info['episode']['r'])

        # If done then clean the history of observations.
        masks = torch.FloatTensor([[0.0] if done_ else [1.0]
                                   for done_ in done])
        rollouts.insert(obs, recurrent_hidden_states, action, action_log_prob, value, reward, masks)

    with torch.no_grad():
        next_value = actor_critic.get_value(rollouts.obs[-1],
                                            rollouts.recurrent_hidden_states[-1],
                                            rollouts.masks[-1]).detach()

    rollouts.compute_returns(next_value, args.use_gae, args.gamma, args.tau)

    value_loss, action_loss, dist_entropy = agent.update(rollouts)

    rollouts.after_update()

    # save for every interval-th episode or for the last epoch
    if (j % args.save_interval == 0 or j == num_updates - 1) and args.save_dir != "":
        save_path = os.path.join(args.save_dir, args.algo)
        try:
            os.makedirs(save_path)
        except OSError:
            pass

        # A really ugly way to save a model to CPU
        save_model = actor_critic
        if args.cuda:
            save_model = copy.deepcopy(actor_critic).cpu()

        save_model = [save_model,
                      getattr(get_vec_normalize(envs), 'ob_rms', None)]

        torch.save(save_model, os.path.join(save_path, args.env_name + ".pt"))

    total_num_steps = (j + 1) * args.num_processes * args.num_steps

#     if j % args.log_interval == 0 and len(episode_rewards) > 1:
    if len(episode_rewards) > 1:
        end = time.time()
        print("Updates {}, num timesteps {}, FPS {} \n Last {} training episodes: mean/median reward {:.1f}/{:.1f}, min/max reward {:.1f}/{:.1f}\n".
            format(j, total_num_steps,
                   int(total_num_steps / (end - start)),
                   len(episode_rewards),
                   np.mean(episode_rewards),
                   np.median(episode_rewards),
                   np.min(episode_rewards),
                   np.max(episode_rewards), dist_entropy,
                   value_loss, action_loss))

        training_stats['updates'].append(j)
        training_stats['num_timesteps'].append(total_num_steps)
        training_stats['mean_reward'].append(np.mean(episode_rewards))
        training_stats['median_reward'].append(np.median(episode_rewards))
        training_stats['min_reward'].append(np.min(episode_rewards))
        training_stats['max_reward'].append(np.max(episode_rewards))

    if (args.eval_interval is not None
            and len(episode_rewards) > 1
            and j % args.eval_interval == 0):
        eval_envs = make_vec_envs(
            args.env_name, args.seed + args.num_processes, args.num_processes,
            args.gamma, eval_log_dir, args.add_timestep, device, True)

        vec_norm = get_vec_normalize(eval_envs)
        if vec_norm is not None:
            vec_norm.eval()
            vec_norm.ob_rms = get_vec_normalize(envs).ob_rms

        eval_episode_rewards = []

        obs = eval_envs.reset()
        eval_recurrent_hidden_states = torch.zeros(args.num_processes,
                        actor_critic.recurrent_hidden_state_size, device=device)
        eval_masks = torch.zeros(args.num_processes, 1, device=device)

        while len(eval_episode_rewards) < 10:
            with torch.no_grad():
                _, action, _, eval_recurrent_hidden_states = actor_critic.act(
                    obs, eval_recurrent_hidden_states, eval_masks, deterministic=True)

            # Obser reward and next obs
            obs, reward, done, infos = eval_envs.step(action)

            eval_masks = torch.FloatTensor([[0.0] if done_ else [1.0]
                                            for done_ in done]).to(device)
            for info in infos:
                if info is not None and 'episode' in info.keys():
                    eval_episode_rewards.append(info['episode']['r'])

        eval_envs.close()

        print(" Evaluation using {} episodes: mean reward {:.5f}\n".
            format(len(eval_episode_rewards),
                   np.mean(eval_episode_rewards)))

    if args.vis and j % args.vis_interval == 0:
        try:
            # Sometimes monitor doesn't properly flush the outputs
            win = visdom_plot(viz, win, args.log_dir, args.env_name,
                              args.algo, args.num_env_steps)
        except IOError:
            pass
# Out:
# Updates 0, num timesteps 60, FPS 279
#  Last 6 training episodes: mean/median reward -5.0/-5.0, min/max reward -5.0/-5.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 1, num timesteps 120, FPS 28
#  Last 7 training episodes: mean/median reward -5.0/-5.0, min/max reward -5.0/-5.0
#
# Updates 2, num timesteps 180, FPS 42
#  Last 10 training episodes: mean/median reward -4.1/-5.0, min/max reward -5.0/-2.0
#
# Updates 3, num timesteps 240, FPS 55
#  Last 10 training episodes: mean/median reward -3.6/-4.5, min/max reward -5.0/-1.0
#
# Updates 4, num timesteps 300, FPS 67
#  Last 10 training episodes: mean/median reward -3.9/-4.0, min/max reward -5.0/-1.0
#
# Updates 5, num timesteps 360, FPS 79
#  Last 10 training episodes: mean/median reward -4.3/-4.0, min/max reward -5.0/-3.0
#
# Updates 6, num timesteps 420, FPS 91
#  Last 10 training episodes: mean/median reward -3.6/-4.0, min/max reward -5.0/1.0
#
# Updates 7, num timesteps 480, FPS 103
#  Last 10 training episodes: mean/median reward -3.6/-4.0, min/max reward -5.0/1.0
#
# Updates 8, num timesteps 540, FPS 114
#  Last 10 training episodes: mean/median reward -4.1/-4.5, min/max reward -5.0/-2.0
#
# Updates 9, num timesteps 600, FPS 125
#  Last 10 training episodes: mean/median reward -3.3/-3.5, min/max reward -5.0/0.0
#
# Updates 10, num timesteps 660, FPS 135
#  Last 10 training episodes: mean/median reward -3.3/-3.5, min/max reward -5.0/0.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 11, num timesteps 720, FPS 91
#  Last 10 training episodes: mean/median reward -2.1/-2.0, min/max reward -5.0/0.0
#
# Updates 12, num timesteps 780, FPS 98
#  Last 10 training episodes: mean/median reward -2.7/-2.5, min/max reward -5.0/0.0
#
# Updates 13, num timesteps 840, FPS 105
#  Last 10 training episodes: mean/median reward -3.2/-3.5, min/max reward -5.0/0.0
#
# Updates 14, num timesteps 900, FPS 112
#  Last 10 training episodes: mean/median reward -3.1/-3.0, min/max reward -5.0/0.0
#
# Updates 15, num timesteps 960, FPS 118
#  Last 10 training episodes: mean/median reward -3.5/-3.5, min/max reward -5.0/0.0
#
# Updates 16, num timesteps 1020, FPS 125
#  Last 10 training episodes: mean/median reward -2.8/-3.0, min/max reward -5.0/1.0
#
# Updates 17, num timesteps 1080, FPS 132
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -5.0/4.0
#
# Updates 18, num timesteps 1140, FPS 138
#  Last 10 training episodes: mean/median reward -2.0/-3.0, min/max reward -5.0/4.0
#
# Updates 19, num timesteps 1200, FPS 144
#  Last 10 training episodes: mean/median reward -1.8/-3.0, min/max reward -4.0/4.0
#
# Updates 20, num timesteps 1260, FPS 150
#  Last 10 training episodes: mean/median reward -2.1/-3.0, min/max reward -4.0/4.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 21, num timesteps 1320, FPS 117
#  Last 10 training episodes: mean/median reward -2.7/-3.0, min/max reward -3.0/0.0
#
# Updates 22, num timesteps 1380, FPS 122
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/0.0
#
# Updates 23, num timesteps 1440, FPS 127
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/0.0
#
# Updates 24, num timesteps 1500, FPS 131
#  Last 10 training episodes: mean/median reward -2.7/-3.0, min/max reward -3.0/0.0
#
# Updates 25, num timesteps 1560, FPS 135
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/0.0
#
# Updates 26, num timesteps 1620, FPS 140
#  Last 10 training episodes: mean/median reward -2.6/-3.0, min/max reward -3.0/-1.0
#
# Updates 27, num timesteps 1680, FPS 144
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/-1.0
#
# Updates 28, num timesteps 1740, FPS 148
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/-1.0
#
# Updates 29, num timesteps 1800, FPS 153
#  Last 10 training episodes: mean/median reward -2.6/-3.0, min/max reward -3.0/-1.0
#
# Updates 30, num timesteps 1860, FPS 157
#  Last 10 training episodes: mean/median reward -2.6/-3.0, min/max reward -3.0/-1.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 31, num timesteps 1920, FPS 130
#  Last 10 training episodes: mean/median reward -2.7/-3.0, min/max reward -5.0/-1.0
#
# Updates 32, num timesteps 1980, FPS 134
#  Last 10 training episodes: mean/median reward -3.3/-3.0, min/max reward -5.0/-2.0
#
# Updates 33, num timesteps 2040, FPS 137
#  Last 10 training episodes: mean/median reward -2.2/-2.5, min/max reward -5.0/7.0
#
# Updates 34, num timesteps 2100, FPS 141
#  Last 10 training episodes: mean/median reward -2.1/-2.0, min/max reward -5.0/7.0
#
# Updates 35, num timesteps 2160, FPS 144
#  Last 10 training episodes: mean/median reward -2.3/-2.5, min/max reward -5.0/7.0
#
# Updates 36, num timesteps 2220, FPS 147
#  Last 10 training episodes: mean/median reward -1.8/-2.5, min/max reward -5.0/7.0
#
# Updates 37, num timesteps 2280, FPS 151
#  Last 10 training episodes: mean/median reward -0.8/-2.0, min/max reward -4.0/7.0
#
# Updates 38, num timesteps 2340, FPS 154
#  Last 10 training episodes: mean/median reward -0.9/-2.5, min/max reward -4.0/7.0
#
# Updates 39, num timesteps 2400, FPS 157
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -3.0/3.0
#
# Updates 40, num timesteps 2460, FPS 161
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/3.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 41, num timesteps 2520, FPS 138
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 42, num timesteps 2580, FPS 141
#  Last 10 training episodes: mean/median reward -3.1/-3.0, min/max reward -5.0/-2.0
#
# Updates 43, num timesteps 2640, FPS 143
#  Last 10 training episodes: mean/median reward -3.1/-3.0, min/max reward -5.0/-2.0
#
# Updates 44, num timesteps 2700, FPS 146
#  Last 10 training episodes: mean/median reward -3.2/-3.0, min/max reward -5.0/-3.0
#
# Updates 45, num timesteps 2760, FPS 149
#  Last 10 training episodes: mean/median reward -3.1/-3.0, min/max reward -5.0/-2.0
#
# Updates 46, num timesteps 2820, FPS 152
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 47, num timesteps 2880, FPS 154
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 48, num timesteps 2940, FPS 157
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 49, num timesteps 3000, FPS 160
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 50, num timesteps 3060, FPS 162
#  Last 10 training episodes: mean/median reward -2.5/-3.0, min/max reward -3.0/0.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 51, num timesteps 3120, FPS 143
#  Last 10 training episodes: mean/median reward -2.8/-3.0, min/max reward -5.0/0.0
#
# Updates 52, num timesteps 3180, FPS 145
#  Last 10 training episodes: mean/median reward -2.0/-3.0, min/max reward -5.0/2.0
#
# Updates 53, num timesteps 3240, FPS 148
#  Last 10 training episodes: mean/median reward -2.0/-3.0, min/max reward -5.0/2.0
#
# Updates 54, num timesteps 3300, FPS 150
#  Last 10 training episodes: mean/median reward -2.1/-3.0, min/max reward -5.0/2.0
#
# Updates 55, num timesteps 3360, FPS 152
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -5.0/2.0
#
# Updates 56, num timesteps 3420, FPS 154
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/-1.0
#
# Updates 57, num timesteps 3480, FPS 157
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/-1.0
#
# Updates 58, num timesteps 3540, FPS 159
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -3.0/-1.0
#
# Updates 59, num timesteps 3600, FPS 161
#  Last 10 training episodes: mean/median reward -1.5/-2.0, min/max reward -3.0/2.0
#
# Updates 60, num timesteps 3660, FPS 163
#  Last 10 training episodes: mean/median reward -2.1/-2.5, min/max reward -5.0/2.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 61, num timesteps 3720, FPS 148
#  Last 10 training episodes: mean/median reward -1.8/-1.5, min/max reward -5.0/2.0
#
# Updates 62, num timesteps 3780, FPS 150
#  Last 10 training episodes: mean/median reward -1.7/-1.5, min/max reward -5.0/2.0
#
# Updates 63, num timesteps 3840, FPS 152
#  Last 10 training episodes: mean/median reward -1.5/-1.5, min/max reward -5.0/2.0
# Updates 64, num timesteps 3900, FPS 154
#  Last 10 training episodes: mean/median reward -1.5/-1.5, min/max reward -5.0/2.0
#
# Updates 65, num timesteps 3960, FPS 156
#  Last 10 training episodes: mean/median reward -1.4/-1.5, min/max reward -5.0/2.0
#
# Updates 66, num timesteps 4020, FPS 158
#  Last 10 training episodes: mean/median reward -1.7/-2.0, min/max reward -5.0/2.0
#
# Updates 67, num timesteps 4080, FPS 160
#  Last 10 training episodes: mean/median reward -1.6/-2.5, min/max reward -5.0/5.0
#
# Updates 68, num timesteps 4140, FPS 162
#  Last 10 training episodes: mean/median reward -2.1/-3.0, min/max reward -5.0/5.0
#
# Updates 69, num timesteps 4200, FPS 164
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -5.0/5.0
#
# Updates 70, num timesteps 4260, FPS 166
#  Last 10 training episodes: mean/median reward -2.8/-3.0, min/max reward -3.0/-2.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 71, num timesteps 4320, FPS 151
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 72, num timesteps 4380, FPS 153
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 73, num timesteps 4440, FPS 155
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 74, num timesteps 4500, FPS 156
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 75, num timesteps 4560, FPS 158
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 76, num timesteps 4620, FPS 160
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 77, num timesteps 4680, FPS 162
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 78, num timesteps 4740, FPS 163
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 79, num timesteps 4800, FPS 165
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 80, num timesteps 4860, FPS 166
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 81, num timesteps 4920, FPS 152
#  Last 10 training episodes: mean/median reward -2.9/-3.0, min/max reward -3.0/-2.0
#
# Updates 82, num timesteps 4980, FPS 153
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 83, num timesteps 5040, FPS 155
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 84, num timesteps 5100, FPS 156
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 85, num timesteps 5160, FPS 157
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -3.0/-3.0
#
# Updates 86, num timesteps 5220, FPS 159
#  Last 10 training episodes: mean/median reward -3.2/-3.0, min/max reward -5.0/-3.0
#
# Updates 87, num timesteps 5280, FPS 160
#  Last 10 training episodes: mean/median reward -3.0/-3.0, min/max reward -5.0/-1.0
#
# Updates 88, num timesteps 5340, FPS 162
#  Last 10 training episodes: mean/median reward -2.5/-3.0, min/max reward -5.0/0.0
#
# Updates 89, num timesteps 5400, FPS 163
#  Last 10 training episodes: mean/median reward -1.8/-2.5, min/max reward -5.0/3.0
#
# Updates 90, num timesteps 5460, FPS 165
#  Last 10 training episodes: mean/median reward -1.8/-2.5, min/max reward -5.0/3.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 91, num timesteps 5520, FPS 153
#  Last 10 training episodes: mean/median reward -1.8/-2.5, min/max reward -5.0/3.0
#
# Updates 92, num timesteps 5580, FPS 155
#  Last 10 training episodes: mean/median reward -2.1/-3.0, min/max reward -5.0/3.0
#
# Updates 93, num timesteps 5640, FPS 156
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -5.0/3.0
#
# Updates 94, num timesteps 5700, FPS 158
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -5.0/3.0
#
# Updates 95, num timesteps 5760, FPS 159
#  Last 10 training episodes: mean/median reward -1.5/-2.0, min/max reward -5.0/2.0
#
# Updates 96, num timesteps 5820, FPS 160
#  Last 10 training episodes: mean/median reward -1.1/-1.5, min/max reward -5.0/2.0
#
# Updates 97, num timesteps 5880, FPS 162
#  Last 10 training episodes: mean/median reward -1.0/-1.5, min/max reward -5.0/2.0
#
# Updates 98, num timesteps 5940, FPS 163
#  Last 10 training episodes: mean/median reward -0.4/0.0, min/max reward -5.0/2.0
#
# Updates 99, num timesteps 6000, FPS 165
#  Last 10 training episodes: mean/median reward -1.5/-1.5, min/max reward -5.0/2.0
#
# Updates 100, num timesteps 6060, FPS 166
#  Last 10 training episodes: mean/median reward -1.9/-2.0, min/max reward -5.0/2.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 101, num timesteps 6120, FPS 156
#  Last 10 training episodes: mean/median reward -2.4/-3.0, min/max reward -5.0/2.0
#
# Updates 102, num timesteps 6180, FPS 157
#  Last 10 training episodes: mean/median reward -1.9/-3.0, min/max reward -5.0/3.0
#
# Updates 103, num timesteps 6240, FPS 158
#  Last 10 training episodes: mean/median reward -2.1/-3.0, min/max reward -5.0/3.0
#
# Updates 104, num timesteps 6300, FPS 160
#  Last 10 training episodes: mean/median reward -1.8/-3.0, min/max reward -5.0/4.0
#
# Updates 105, num timesteps 6360, FPS 161
#  Last 10 training episodes: mean/median reward -1.8/-3.0, min/max reward -5.0/4.0
#
# Updates 106, num timesteps 6420, FPS 162
#  Last 10 training episodes: mean/median reward -1.4/-3.0, min/max reward -5.0/5.0
#
# Updates 107, num timesteps 6480, FPS 164
#  Last 10 training episodes: mean/median reward 0.1/-1.0, min/max reward -5.0/8.0
#
# Updates 108, num timesteps 6540, FPS 165
#  Last 10 training episodes: mean/median reward 0.5/1.0, min/max reward -5.0/8.0
#
# Updates 109, num timesteps 6600, FPS 166
#  Last 10 training episodes: mean/median reward 0.5/1.0, min/max reward -5.0/8.0
#
# Updates 110, num timesteps 6660, FPS 167
#  Last 10 training episodes: mean/median reward 0.0/1.0, min/max reward -5.0/8.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 111, num timesteps 6720, FPS 158
#  Last 10 training episodes: mean/median reward 0.0/1.0, min/max reward -5.0/8.0
#
# Updates 112, num timesteps 6780, FPS 159
#  Last 10 training episodes: mean/median reward 0.3/1.0, min/max reward -5.0/8.0
#
# Updates 113, num timesteps 6840, FPS 160
#  Last 10 training episodes: mean/median reward 1.6/1.0, min/max reward -3.0/8.0
#
# Updates 114, num timesteps 6900, FPS 161
#  Last 10 training episodes: mean/median reward 0.8/1.0, min/max reward -3.0/8.0
#
# Updates 115, num timesteps 6960, FPS 163
#  Last 10 training episodes: mean/median reward -0.3/1.0, min/max reward -3.0/2.0
#
# Updates 116, num timesteps 7020, FPS 164
#  Last 10 training episodes: mean/median reward -0.3/1.0, min/max reward -3.0/2.0
#
# Updates 117, num timesteps 7080, FPS 165
#  Last 10 training episodes: mean/median reward -0.5/0.0, min/max reward -3.0/2.0
#
# Updates 118, num timesteps 7140, FPS 166
#  Last 10 training episodes: mean/median reward -0.1/0.0, min/max reward -3.0/5.0
#
# Updates 119, num timesteps 7200, FPS 167
#  Last 10 training episodes: mean/median reward 2.3/0.0, min/max reward -3.0/21.0
#
# Updates 120, num timesteps 7260, FPS 168
#  Last 10 training episodes: mean/median reward 2.1/0.0, min/max reward -3.0/21.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 121, num timesteps 7320, FPS 159
#  Last 10 training episodes: mean/median reward 2.1/0.0, min/max reward -3.0/21.0
#
# Updates 122, num timesteps 7380, FPS 160
#  Last 10 training episodes: mean/median reward 1.8/-1.5, min/max reward -3.0/21.0
#
# Updates 123, num timesteps 7440, FPS 162
#  Last 10 training episodes: mean/median reward 2.5/0.5, min/max reward -3.0/21.0
#
# Updates 124, num timesteps 7500, FPS 163
#  Last 10 training episodes: mean/median reward 2.5/0.5, min/max reward -3.0/21.0
#
# Updates 125, num timesteps 7560, FPS 164
#  Last 10 training episodes: mean/median reward 3.3/2.0, min/max reward -3.0/21.0
#
# Updates 126, num timesteps 7620, FPS 165
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/21.0
#
# Updates 127, num timesteps 7680, FPS 166
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/21.0
# Updates 128, num timesteps 7740, FPS 167
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/21.0
#
# Updates 129, num timesteps 7800, FPS 168
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/21.0
#
# Updates 130, num timesteps 7860, FPS 169
#  Last 10 training episodes: mean/median reward 3.6/3.0, min/max reward 1.0/12.0
#
#  Evaluation using 10 episodes: mean reward 1.60000
#
# Updates 131, num timesteps 7920, FPS 159
#  Last 10 training episodes: mean/median reward 3.6/3.0, min/max reward 1.0/12.0
#
# Updates 132, num timesteps 7980, FPS 160
#  Last 10 training episodes: mean/median reward 3.6/3.0, min/max reward 1.0/12.0
#
# Updates 133, num timesteps 8040, FPS 161
#  Last 10 training episodes: mean/median reward 3.6/3.0, min/max reward 1.0/12.0
#
# Updates 134, num timesteps 8100, FPS 162
#  Last 10 training episodes: mean/median reward 3.5/3.0, min/max reward 1.0/12.0
#
# Updates 135, num timesteps 8160, FPS 163
#  Last 10 training episodes: mean/median reward 3.7/3.0, min/max reward 1.0/12.0
#
# Updates 136, num timesteps 8220, FPS 164
#  Last 10 training episodes: mean/median reward 4.2/3.0, min/max reward 1.0/12.0
#
# Updates 137, num timesteps 8280, FPS 165
#  Last 10 training episodes: mean/median reward 4.9/3.5, min/max reward 1.0/12.0
#
# Updates 138, num timesteps 8340, FPS 166
#  Last 10 training episodes: mean/median reward 3.5/3.0, min/max reward -2.0/9.0
#
# Updates 139, num timesteps 8400, FPS 167
#  Last 10 training episodes: mean/median reward 3.5/3.0, min/max reward -2.0/9.0
#
# Updates 140, num timesteps 8460, FPS 168
#  Last 10 training episodes: mean/median reward 3.5/3.0, min/max reward -2.0/9.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 141, num timesteps 8520, FPS 160
#  Last 10 training episodes: mean/median reward 4.4/4.0, min/max reward -2.0/9.0
#
# Updates 142, num timesteps 8580, FPS 161
#  Last 10 training episodes: mean/median reward 3.6/3.5, min/max reward -3.0/9.0
#
# Updates 143, num timesteps 8640, FPS 162
#  Last 10 training episodes: mean/median reward 3.1/3.0, min/max reward -3.0/9.0
#
# Updates 144, num timesteps 8700, FPS 163
#  Last 10 training episodes: mean/median reward 4.7/5.0, min/max reward -3.0/17.0
#
# Updates 145, num timesteps 8760, FPS 164
#  Last 10 training episodes: mean/median reward 4.7/5.0, min/max reward -3.0/17.0
#
# Updates 146, num timesteps 8820, FPS 165
#  Last 10 training episodes: mean/median reward 3.8/2.0, min/max reward -3.0/17.0
#
# Updates 147, num timesteps 8880, FPS 166
#  Last 10 training episodes: mean/median reward 3.3/2.0, min/max reward -3.0/17.0
#
# Updates 148, num timesteps 8940, FPS 167
#  Last 10 training episodes: mean/median reward 3.3/2.0, min/max reward -3.0/17.0
#
# Updates 149, num timesteps 9000, FPS 168
#  Last 10 training episodes: mean/median reward 3.3/2.0, min/max reward -3.0/17.0
#
# Updates 150, num timesteps 9060, FPS 168
#  Last 10 training episodes: mean/median reward 2.7/2.0, min/max reward -3.0/17.0
#
#  Evaluation using 10 episodes: mean reward 3.00000
#
# Updates 151, num timesteps 9120, FPS 160
#  Last 10 training episodes: mean/median reward 3.1/2.0, min/max reward -2.0/17.0
#
# Updates 152, num timesteps 9180, FPS 161
#  Last 10 training episodes: mean/median reward 3.8/2.0, min/max reward -2.0/17.0
#
# Updates 153, num timesteps 9240, FPS 162
#  Last 10 training episodes: mean/median reward 3.8/2.0, min/max reward -2.0/17.0
#
# Updates 154, num timesteps 9300, FPS 163
#  Last 10 training episodes: mean/median reward 2.1/1.5, min/max reward -2.0/9.0
#
# Updates 155, num timesteps 9360, FPS 164
#  Last 10 training episodes: mean/median reward 2.4/0.5, min/max reward -2.0/9.0
#
# Updates 156, num timesteps 9420, FPS 164
#  Last 10 training episodes: mean/median reward 2.1/0.5, min/max reward -2.0/9.0
#
# Updates 157, num timesteps 9480, FPS 165
#  Last 10 training episodes: mean/median reward 2.1/0.5, min/max reward -2.0/9.0
#
# Updates 158, num timesteps 9540, FPS 166
#  Last 10 training episodes: mean/median reward 2.7/1.0, min/max reward -2.0/9.0
#
# Updates 159, num timesteps 9600, FPS 167
#  Last 10 training episodes: mean/median reward 2.7/1.0, min/max reward -2.0/9.0
#
# Updates 160, num timesteps 9660, FPS 168
#  Last 10 training episodes: mean/median reward 2.4/1.0, min/max reward -2.0/9.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 161, num timesteps 9720, FPS 160
#  Last 10 training episodes: mean/median reward 2.4/1.0, min/max reward -2.0/9.0
#
# Updates 162, num timesteps 9780, FPS 160
#  Last 10 training episodes: mean/median reward 3.4/2.5, min/max reward -2.0/10.0
#
# Updates 163, num timesteps 9840, FPS 161
#  Last 10 training episodes: mean/median reward 3.6/3.5, min/max reward -2.0/10.0
#
# Updates 164, num timesteps 9900, FPS 162
#  Last 10 training episodes: mean/median reward 4.0/3.5, min/max reward -2.0/13.0
#
# Updates 165, num timesteps 9960, FPS 162
#  Last 10 training episodes: mean/median reward 3.8/3.5, min/max reward -2.0/13.0
#
# Updates 166, num timesteps 10020, FPS 163
#  Last 10 training episodes: mean/median reward 3.8/3.5, min/max reward -2.0/13.0
#
# Updates 167, num timesteps 10080, FPS 164
#  Last 10 training episodes: mean/median reward 3.8/3.5, min/max reward -2.0/13.0
#
# Updates 168, num timesteps 10140, FPS 164
#  Last 10 training episodes: mean/median reward 4.2/4.0, min/max reward -2.0/13.0
#
# Updates 169, num timesteps 10200, FPS 165
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward -2.0/13.0
#
# Updates 170, num timesteps 10260, FPS 166
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward -2.0/13.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 171, num timesteps 10320, FPS 158
#  Last 10 training episodes: mean/median reward 3.3/2.5, min/max reward -2.0/13.0
#
# Updates 172, num timesteps 10380, FPS 159
#  Last 10 training episodes: mean/median reward 3.3/2.5, min/max reward -2.0/13.0
#
# Updates 173, num timesteps 10440, FPS 159
#  Last 10 training episodes: mean/median reward 3.1/2.0, min/max reward -2.0/13.0
#
# Updates 174, num timesteps 10500, FPS 160
#  Last 10 training episodes: mean/median reward 1.7/1.5, min/max reward -2.0/5.0
#
# Updates 175, num timesteps 10560, FPS 161
#  Last 10 training episodes: mean/median reward 2.2/1.5, min/max reward -3.0/10.0
#
# Updates 176, num timesteps 10620, FPS 162
#  Last 10 training episodes: mean/median reward 2.2/1.5, min/max reward -3.0/10.0
#
# Updates 177, num timesteps 10680, FPS 162
#  Last 10 training episodes: mean/median reward 3.2/2.0, min/max reward -3.0/11.0
#
# Updates 178, num timesteps 10740, FPS 163
#  Last 10 training episodes: mean/median reward 3.2/2.0, min/max reward -3.0/11.0
#
# Updates 179, num timesteps 10800, FPS 164
#  Last 10 training episodes: mean/median reward 3.4/2.5, min/max reward -3.0/11.0
#
# Updates 180, num timesteps 10860, FPS 164
#  Last 10 training episodes: mean/median reward 4.3/4.0, min/max reward -3.0/11.0
#
#  Evaluation using 10 episodes: mean reward 10.20000
#
# Updates 181, num timesteps 10920, FPS 153
#  Last 10 training episodes: mean/median reward 4.3/4.0, min/max reward -3.0/11.0
#
# Updates 182, num timesteps 10980, FPS 154
#  Last 10 training episodes: mean/median reward 4.3/4.0, min/max reward -3.0/11.0
#
# Updates 183, num timesteps 11040, FPS 155
#  Last 10 training episodes: mean/median reward 4.5/4.0, min/max reward -3.0/11.0
#
# Updates 184, num timesteps 11100, FPS 155
#  Last 10 training episodes: mean/median reward 4.0/4.0, min/max reward -3.0/11.0
#
# Updates 185, num timesteps 11160, FPS 156
#  Last 10 training episodes: mean/median reward 4.0/4.0, min/max reward -3.0/11.0
#
# Updates 186, num timesteps 11220, FPS 157
#  Last 10 training episodes: mean/median reward 4.1/4.0, min/max reward -3.0/11.0
#
# Updates 187, num timesteps 11280, FPS 157
#  Last 10 training episodes: mean/median reward 2.8/3.5, min/max reward -3.0/10.0
#
# Updates 188, num timesteps 11340, FPS 158
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -3.0/10.0
#
# Updates 189, num timesteps 11400, FPS 159
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -3.0/10.0
#
# Updates 190, num timesteps 11460, FPS 159
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -3.0/10.0
#
#  Evaluation using 10 episodes: mean reward 9.50000
#
# Updates 191, num timesteps 11520, FPS 150
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -3.0/10.0
#
# Updates 192, num timesteps 11580, FPS 151
#  Last 10 training episodes: mean/median reward 2.8/3.0, min/max reward -3.0/11.0
# Updates 193, num timesteps 11640, FPS 151
#  Last 10 training episodes: mean/median reward 2.8/3.0, min/max reward -3.0/11.0
#
# Updates 194, num timesteps 11700, FPS 152
#  Last 10 training episodes: mean/median reward 2.8/3.0, min/max reward -3.0/11.0
#
# Updates 195, num timesteps 11760, FPS 153
#  Last 10 training episodes: mean/median reward 2.8/3.0, min/max reward -3.0/11.0
#
# Updates 196, num timesteps 11820, FPS 153
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -3.0/11.0
#
# Updates 197, num timesteps 11880, FPS 154
#  Last 10 training episodes: mean/median reward 5.5/4.0, min/max reward -2.0/25.0
#
# Updates 198, num timesteps 11940, FPS 155
#  Last 10 training episodes: mean/median reward 5.6/4.5, min/max reward -2.0/25.0
#
# Updates 199, num timesteps 12000, FPS 155
#  Last 10 training episodes: mean/median reward 5.6/4.5, min/max reward -2.0/25.0
#
# Updates 200, num timesteps 12060, FPS 156
#  Last 10 training episodes: mean/median reward 6.1/4.5, min/max reward -2.0/25.0
#
#  Evaluation using 10 episodes: mean reward 4.00000
#
# Updates 201, num timesteps 12120, FPS 150
#  Last 10 training episodes: mean/median reward 6.1/4.5, min/max reward -2.0/25.0
#
# Updates 202, num timesteps 12180, FPS 151
#  Last 10 training episodes: mean/median reward 6.9/5.0, min/max reward 1.0/25.0
#
# Updates 203, num timesteps 12240, FPS 151
#  Last 10 training episodes: mean/median reward 7.5/5.5, min/max reward 1.0/25.0
#
# Updates 204, num timesteps 12300, FPS 152
#  Last 10 training episodes: mean/median reward 6.6/5.0, min/max reward 1.0/25.0
#
# Updates 205, num timesteps 12360, FPS 153
#  Last 10 training episodes: mean/median reward 6.6/5.0, min/max reward 1.0/25.0
#
# Updates 206, num timesteps 12420, FPS 153
#  Last 10 training episodes: mean/median reward 7.1/4.5, min/max reward 2.0/25.0
#
# Updates 207, num timesteps 12480, FPS 154
#  Last 10 training episodes: mean/median reward 7.1/4.5, min/max reward 2.0/25.0
#
# Updates 208, num timesteps 12540, FPS 155
#  Last 10 training episodes: mean/median reward 7.1/4.5, min/max reward 2.0/25.0
#
# Updates 209, num timesteps 12600, FPS 155
#  Last 10 training episodes: mean/median reward 7.1/4.5, min/max reward 2.0/25.0
#
# Updates 210, num timesteps 12660, FPS 156
#  Last 10 training episodes: mean/median reward 6.9/4.5, min/max reward 2.0/25.0
#
#  Evaluation using 10 episodes: mean reward -3.00000
#
# Updates 211, num timesteps 12720, FPS 151
#  Last 10 training episodes: mean/median reward 4.9/4.5, min/max reward 2.0/12.0
#
# Updates 212, num timesteps 12780, FPS 152
#  Last 10 training episodes: mean/median reward 4.9/4.5, min/max reward 2.0/12.0
#
# Updates 213, num timesteps 12840, FPS 152
#  Last 10 training episodes: mean/median reward 4.9/4.5, min/max reward 2.0/12.0
#
# Updates 214, num timesteps 12900, FPS 153
#  Last 10 training episodes: mean/median reward 5.4/4.5, min/max reward 2.0/12.0
#
# Updates 215, num timesteps 12960, FPS 153
#  Last 10 training episodes: mean/median reward 6.1/4.5, min/max reward -3.0/19.0
#
# Updates 216, num timesteps 13020, FPS 154
#  Last 10 training episodes: mean/median reward 6.1/4.5, min/max reward -3.0/19.0
#
# Updates 217, num timesteps 13080, FPS 155
#  Last 10 training episodes: mean/median reward 6.1/4.5, min/max reward -3.0/19.0
#
# Updates 218, num timesteps 13140, FPS 155
#  Last 10 training episodes: mean/median reward 5.9/3.5, min/max reward -3.0/19.0
#
# Updates 219, num timesteps 13200, FPS 156
#  Last 10 training episodes: mean/median reward 6.0/3.5, min/max reward -3.0/19.0
#
# Updates 220, num timesteps 13260, FPS 156
#  Last 10 training episodes: mean/median reward 5.5/3.5, min/max reward -3.0/19.0
#
#  Evaluation using 10 episodes: mean reward 11.30000
#
# Updates 221, num timesteps 13320, FPS 148
#  Last 10 training episodes: mean/median reward 5.5/3.5, min/max reward -3.0/19.0
#
# Updates 222, num timesteps 13380, FPS 149
#  Last 10 training episodes: mean/median reward 5.5/3.5, min/max reward -3.0/19.0
#
# Updates 223, num timesteps 13440, FPS 149
#  Last 10 training episodes: mean/median reward 5.4/3.0, min/max reward -3.0/19.0
#
# Updates 224, num timesteps 13500, FPS 150
#  Last 10 training episodes: mean/median reward 5.4/3.0, min/max reward -3.0/19.0
#
# Updates 225, num timesteps 13560, FPS 150
#  Last 10 training episodes: mean/median reward 5.4/3.0, min/max reward -3.0/19.0
#
# Updates 226, num timesteps 13620, FPS 151
#  Last 10 training episodes: mean/median reward 5.4/3.0, min/max reward -3.0/19.0
#
# Updates 227, num timesteps 13680, FPS 151
#  Last 10 training episodes: mean/median reward 4.8/3.0, min/max reward -3.0/14.0
#
# Updates 228, num timesteps 13740, FPS 152
#  Last 10 training episodes: mean/median reward 4.5/3.0, min/max reward -3.0/14.0
#
# Updates 229, num timesteps 13800, FPS 153
#  Last 10 training episodes: mean/median reward 4.5/3.0, min/max reward -3.0/14.0
#
# Updates 230, num timesteps 13860, FPS 153
#  Last 10 training episodes: mean/median reward 4.5/3.0, min/max reward -3.0/14.0
#
#  Evaluation using 10 episodes: mean reward 8.00000
#
# Updates 231, num timesteps 13920, FPS 148
#  Last 10 training episodes: mean/median reward 4.8/3.5, min/max reward -3.0/14.0
#
# Updates 232, num timesteps 13980, FPS 148
#  Last 10 training episodes: mean/median reward 4.0/3.5, min/max reward -3.0/14.0
#
# Updates 233, num timesteps 14040, FPS 148
#  Last 10 training episodes: mean/median reward 5.0/4.0, min/max reward -2.0/14.0
#
# Updates 234, num timesteps 14100, FPS 149
#  Last 10 training episodes: mean/median reward 5.0/4.0, min/max reward -2.0/14.0
#
# Updates 235, num timesteps 14160, FPS 150
#  Last 10 training episodes: mean/median reward 5.0/4.0, min/max reward -2.0/14.0
#
# Updates 236, num timesteps 14220, FPS 150
#  Last 10 training episodes: mean/median reward 5.5/4.5, min/max reward -2.0/14.0
#
# Updates 237, num timesteps 14280, FPS 151
#  Last 10 training episodes: mean/median reward 5.0/4.5, min/max reward -2.0/14.0
#
# Updates 238, num timesteps 14340, FPS 151
#  Last 10 training episodes: mean/median reward 4.5/4.5, min/max reward -2.0/10.0
#
# Updates 239, num timesteps 14400, FPS 152
#  Last 10 training episodes: mean/median reward 4.3/4.5, min/max reward -2.0/10.0
#
# Updates 240, num timesteps 14460, FPS 152
#  Last 10 training episodes: mean/median reward 4.3/4.5, min/max reward -2.0/10.0
#
#  Evaluation using 10 episodes: mean reward 6.00000
#
# Updates 241, num timesteps 14520, FPS 147
#  Last 10 training episodes: mean/median reward 4.9/5.0, min/max reward 1.0/10.0
#
# Updates 242, num timesteps 14580, FPS 148
#  Last 10 training episodes: mean/median reward 4.9/5.0, min/max reward 1.0/10.0
#
# Updates 243, num timesteps 14640, FPS 148
#  Last 10 training episodes: mean/median reward 4.9/5.0, min/max reward 1.0/10.0
#
# Updates 244, num timesteps 14700, FPS 149
#  Last 10 training episodes: mean/median reward 4.9/5.0, min/max reward 1.0/10.0
#
# Updates 245, num timesteps 14760, FPS 149
#  Last 10 training episodes: mean/median reward 5.1/5.0, min/max reward 1.0/10.0
#
# Updates 246, num timesteps 14820, FPS 150
#  Last 10 training episodes: mean/median reward 5.3/5.0, min/max reward 1.0/10.0
#
# Updates 247, num timesteps 14880, FPS 150
#  Last 10 training episodes: mean/median reward 5.3/5.0, min/max reward 1.0/10.0
#
# Updates 248, num timesteps 14940, FPS 151
#  Last 10 training episodes: mean/median reward 4.5/4.0, min/max reward 1.0/9.0
#
# Updates 249, num timesteps 15000, FPS 151
#  Last 10 training episodes: mean/median reward 4.4/3.5, min/max reward 1.0/9.0
#
# Updates 250, num timesteps 15060, FPS 152
#  Last 10 training episodes: mean/median reward 4.0/3.5, min/max reward 1.0/9.0
#
#  Evaluation using 10 episodes: mean reward 2.70000
#
# Updates 251, num timesteps 15120, FPS 147
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward 1.0/9.0
#
# Updates 252, num timesteps 15180, FPS 147
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward 1.0/9.0
#
# Updates 253, num timesteps 15240, FPS 148
#  Last 10 training episodes: mean/median reward 4.2/3.5, min/max reward 1.0/9.0
#
# Updates 254, num timesteps 15300, FPS 148
#  Last 10 training episodes: mean/median reward 4.2/3.5, min/max reward 1.0/9.0
#
# Updates 255, num timesteps 15360, FPS 149
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -2.0/5.0
#
# Updates 256, num timesteps 15420, FPS 149
#  Last 10 training episodes: mean/median reward 2.7/3.0, min/max reward -2.0/5.0
# Updates 257, num timesteps 15480, FPS 150
#  Last 10 training episodes: mean/median reward 3.0/3.5, min/max reward -2.0/6.0
#
# Updates 258, num timesteps 15540, FPS 150
#  Last 10 training episodes: mean/median reward 3.0/3.5, min/max reward -2.0/6.0
#
# Updates 259, num timesteps 15600, FPS 151
#  Last 10 training episodes: mean/median reward 3.0/3.5, min/max reward -2.0/6.0
#
# Updates 260, num timesteps 15660, FPS 151
#  Last 10 training episodes: mean/median reward 3.0/3.5, min/max reward -2.0/6.0
#
#  Evaluation using 10 episodes: mean reward 5.60000
#
# Updates 261, num timesteps 15720, FPS 147
#  Last 10 training episodes: mean/median reward 2.9/3.0, min/max reward -2.0/6.0
#
# Updates 262, num timesteps 15780, FPS 147
#  Last 10 training episodes: mean/median reward 3.5/3.0, min/max reward -2.0/11.0
#
# Updates 263, num timesteps 15840, FPS 148
#  Last 10 training episodes: mean/median reward 4.7/3.5, min/max reward -2.0/14.0
#
# Updates 264, num timesteps 15900, FPS 148
#  Last 10 training episodes: mean/median reward 4.5/3.5, min/max reward -2.0/14.0
#
# Updates 265, num timesteps 15960, FPS 149
#  Last 10 training episodes: mean/median reward 4.5/3.5, min/max reward -2.0/14.0
#
# Updates 266, num timesteps 16020, FPS 149
#  Last 10 training episodes: mean/median reward 4.5/3.5, min/max reward -2.0/14.0
#
# Updates 267, num timesteps 16080, FPS 150
#  Last 10 training episodes: mean/median reward 4.9/3.0, min/max reward 1.0/14.0
#
# Updates 268, num timesteps 16140, FPS 150
#  Last 10 training episodes: mean/median reward 4.5/3.0, min/max reward 1.0/14.0
#
# Updates 269, num timesteps 16200, FPS 150
#  Last 10 training episodes: mean/median reward 4.5/3.0, min/max reward 1.0/14.0
#
# Updates 270, num timesteps 16260, FPS 151
#  Last 10 training episodes: mean/median reward 4.2/3.0, min/max reward -1.0/14.0
#
#  Evaluation using 10 episodes: mean reward 4.60000
#
# Updates 271, num timesteps 16320, FPS 146
#  Last 10 training episodes: mean/median reward 4.2/3.0, min/max reward -1.0/14.0
#
# Updates 272, num timesteps 16380, FPS 147
#  Last 10 training episodes: mean/median reward 4.2/3.0, min/max reward -1.0/14.0
#
# Updates 273, num timesteps 16440, FPS 147
#  Last 10 training episodes: mean/median reward 4.0/2.5, min/max reward -1.0/14.0
#
# Updates 274, num timesteps 16500, FPS 148
#  Last 10 training episodes: mean/median reward 3.9/2.5, min/max reward -1.0/14.0
#
# Updates 275, num timesteps 16560, FPS 148
#  Last 10 training episodes: mean/median reward 5.0/2.5, min/max reward -1.0/16.0
#
# Updates 276, num timesteps 16620, FPS 149
#  Last 10 training episodes: mean/median reward 5.0/2.5, min/max reward -1.0/16.0
#
# Updates 277, num timesteps 16680, FPS 149
#  Last 10 training episodes: mean/median reward 5.0/2.5, min/max reward -1.0/16.0
#
# Updates 278, num timesteps 16740, FPS 149
#  Last 10 training episodes: mean/median reward 5.0/2.5, min/max reward -1.0/16.0
#
# Updates 279, num timesteps 16800, FPS 150
#  Last 10 training episodes: mean/median reward 6.4/3.0, min/max reward -1.0/22.0
#
# Updates 280, num timesteps 16860, FPS 150
#  Last 10 training episodes: mean/median reward 6.4/3.0, min/max reward -1.0/22.0
#
#  Evaluation using 10 episodes: mean reward 3.80000
#
# Updates 281, num timesteps 16920, FPS 145
#  Last 10 training episodes: mean/median reward 7.1/4.0, min/max reward -1.0/22.0
#
# Updates 282, num timesteps 16980, FPS 145
#  Last 10 training episodes: mean/median reward 6.8/4.0, min/max reward -1.0/22.0
#
# Updates 283, num timesteps 17040, FPS 146
#  Last 10 training episodes: mean/median reward 6.8/4.0, min/max reward -1.0/22.0
#
# Updates 284, num timesteps 17100, FPS 146
#  Last 10 training episodes: mean/median reward 6.8/4.5, min/max reward -3.0/22.0
#
# Updates 285, num timesteps 17160, FPS 146
#  Last 10 training episodes: mean/median reward 6.8/4.5, min/max reward -3.0/22.0
#
# Updates 286, num timesteps 17220, FPS 147
#  Last 10 training episodes: mean/median reward 7.0/4.5, min/max reward -3.0/22.0
#
# Updates 287, num timesteps 17280, FPS 147
#  Last 10 training episodes: mean/median reward 6.1/3.5, min/max reward -3.0/22.0
#
# Updates 288, num timesteps 17340, FPS 147
#  Last 10 training episodes: mean/median reward 6.0/3.5, min/max reward -3.0/22.0
#
# Updates 289, num timesteps 17400, FPS 148
#  Last 10 training episodes: mean/median reward 6.0/3.5, min/max reward -3.0/22.0
#
# Updates 290, num timesteps 17460, FPS 148
#  Last 10 training episodes: mean/median reward 6.4/3.5, min/max reward -3.0/22.0
#
#  Evaluation using 10 episodes: mean reward 1.10000
#
# Updates 291, num timesteps 17520, FPS 140
#  Last 10 training episodes: mean/median reward 3.5/2.5, min/max reward -3.0/15.0
#
# Updates 292, num timesteps 17580, FPS 141
#  Last 10 training episodes: mean/median reward 3.5/2.5, min/max reward -3.0/15.0
#
# Updates 293, num timesteps 17640, FPS 141
#  Last 10 training episodes: mean/median reward 3.5/2.5, min/max reward -3.0/15.0
#
# Updates 294, num timesteps 17700, FPS 142
#  Last 10 training episodes: mean/median reward 4.2/2.5, min/max reward 1.0/15.0
#
# Updates 295, num timesteps 17760, FPS 142
#  Last 10 training episodes: mean/median reward 3.5/2.0, min/max reward -3.0/15.0
#
# Updates 296, num timesteps 17820, FPS 142
#  Last 10 training episodes: mean/median reward 3.7/2.0, min/max reward -3.0/15.0
#
# Updates 297, num timesteps 17880, FPS 143
#  Last 10 training episodes: mean/median reward 3.7/2.0, min/max reward -3.0/15.0
#
# Updates 298, num timesteps 17940, FPS 143
#  Last 10 training episodes: mean/median reward 3.7/2.0, min/max reward -3.0/15.0
#
# Updates 299, num timesteps 18000, FPS 143
#  Last 10 training episodes: mean/median reward 3.7/2.0, min/max reward -3.0/15.0
#
# Updates 300, num timesteps 18060, FPS 144
#  Last 10 training episodes: mean/median reward 3.7/2.0, min/max reward -3.0/15.0
#
#  Evaluation using 10 episodes: mean reward 0.90000
#
# Updates 301, num timesteps 18120, FPS 136
#  Last 10 training episodes: mean/median reward 3.6/2.5, min/max reward -3.0/9.0
#
# Updates 302, num timesteps 18180, FPS 137
#  Last 10 training episodes: mean/median reward 3.6/2.5, min/max reward -3.0/9.0
#
# Updates 303, num timesteps 18240, FPS 137
#  Last 10 training episodes: mean/median reward 3.3/2.0, min/max reward -3.0/9.0
#
# Updates 304, num timesteps 18300, FPS 137
#  Last 10 training episodes: mean/median reward 3.6/2.0, min/max reward -3.0/12.0
#
# Updates 305, num timesteps 18360, FPS 138
#  Last 10 training episodes: mean/median reward 3.6/2.0, min/max reward -3.0/12.0
#
# Updates 306, num timesteps 18420, FPS 138
#  Last 10 training episodes: mean/median reward 3.6/2.0, min/max reward -3.0/12.0
#
# Updates 307, num timesteps 18480, FPS 138
#  Last 10 training episodes: mean/median reward 6.4/3.5, min/max reward -3.0/29.0
#
# Updates 308, num timesteps 18540, FPS 138
#  Last 10 training episodes: mean/median reward 6.4/3.5, min/max reward -3.0/29.0
#
# Updates 309, num timesteps 18600, FPS 139
#  Last 10 training episodes: mean/median reward 7.5/5.5, min/max reward -3.0/29.0
#
# Updates 310, num timesteps 18660, FPS 139
#  Last 10 training episodes: mean/median reward 7.5/5.5, min/max reward -3.0/29.0
#
#  Evaluation using 10 episodes: mean reward 2.60000
#
# Updates 311, num timesteps 18720, FPS 133
#  Last 10 training episodes: mean/median reward 8.9/7.5, min/max reward 0.0/29.0
#
# Updates 312, num timesteps 18780, FPS 133
#  Last 10 training episodes: mean/median reward 8.9/7.5, min/max reward 0.0/29.0
#
# Updates 313, num timesteps 18840, FPS 134
#  Last 10 training episodes: mean/median reward 8.6/7.5, min/max reward 0.0/29.0
#
# Updates 314, num timesteps 18900, FPS 134
#  Last 10 training episodes: mean/median reward 9.1/10.0, min/max reward 0.0/29.0
#
# Updates 315, num timesteps 18960, FPS 134
#  Last 10 training episodes: mean/median reward 8.5/7.0, min/max reward 0.0/29.0
#
# Updates 316, num timesteps 19020, FPS 135
#  Last 10 training episodes: mean/median reward 8.5/7.0, min/max reward 0.0/29.0
#
# Updates 317, num timesteps 19080, FPS 135
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 1.0/29.0
#
# Updates 318, num timesteps 19140, FPS 135
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 1.0/29.0
#
# Updates 319, num timesteps 19200, FPS 135
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 1.0/29.0
#
# Updates 320, num timesteps 19260, FPS 136
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 1.0/29.0
#  Evaluation using 10 episodes: mean reward -2.60000
#
# Updates 321, num timesteps 19320, FPS 131
#  Last 10 training episodes: mean/median reward 6.9/5.5, min/max reward 1.0/16.0
#
# Updates 322, num timesteps 19380, FPS 131
#  Last 10 training episodes: mean/median reward 6.9/5.5, min/max reward 1.0/16.0
#
# Updates 323, num timesteps 19440, FPS 132
#  Last 10 training episodes: mean/median reward 6.4/5.5, min/max reward -3.0/16.0
#
# Updates 324, num timesteps 19500, FPS 132
#  Last 10 training episodes: mean/median reward 5.3/2.0, min/max reward -3.0/16.0
#
# Updates 325, num timesteps 19560, FPS 132
#  Last 10 training episodes: mean/median reward 5.3/2.0, min/max reward -3.0/16.0
#
# Updates 326, num timesteps 19620, FPS 132
#  Last 10 training episodes: mean/median reward 4.2/1.0, min/max reward -3.0/16.0
#
# Updates 327, num timesteps 19680, FPS 133
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/16.0
#
# Updates 328, num timesteps 19740, FPS 133
#  Last 10 training episodes: mean/median reward 4.4/2.0, min/max reward -3.0/16.0
#
# Updates 329, num timesteps 19800, FPS 133
#  Last 10 training episodes: mean/median reward 2.7/1.0, min/max reward -3.0/14.0
#
# Updates 330, num timesteps 19860, FPS 133
#  Last 10 training episodes: mean/median reward 2.7/1.0, min/max reward -3.0/14.0
#
#  Evaluation using 10 episodes: mean reward 3.40000
#
# Updates 331, num timesteps 19920, FPS 127
#  Last 10 training episodes: mean/median reward 2.7/1.0, min/max reward -3.0/14.0
#
# Updates 332, num timesteps 19980, FPS 127
#  Last 10 training episodes: mean/median reward 3.1/2.0, min/max reward -3.0/14.0
#
# Updates 333, num timesteps 20040, FPS 128
#  Last 10 training episodes: mean/median reward 2.5/2.0, min/max reward -3.0/12.0
#
# Updates 334, num timesteps 20100, FPS 128
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward -2.0/13.0
#
# Updates 335, num timesteps 20160, FPS 128
#  Last 10 training episodes: mean/median reward 3.9/3.5, min/max reward -2.0/13.0
#
# Updates 336, num timesteps 20220, FPS 128
#  Last 10 training episodes: mean/median reward 4.1/3.5, min/max reward -2.0/13.0
#
# Updates 337, num timesteps 20280, FPS 129
#  Last 10 training episodes: mean/median reward 3.7/3.0, min/max reward -2.0/13.0
#
# Updates 338, num timesteps 20340, FPS 129
#  Last 10 training episodes: mean/median reward 4.0/3.0, min/max reward -1.0/13.0
#
# Updates 339, num timesteps 20400, FPS 129
#  Last 10 training episodes: mean/median reward 4.0/3.0, min/max reward -1.0/13.0
#
# Updates 340, num timesteps 20460, FPS 129
#  Last 10 training episodes: mean/median reward 4.0/3.0, min/max reward -1.0/13.0
#
#  Evaluation using 10 episodes: mean reward 3.40000
#
# Updates 341, num timesteps 20520, FPS 125
#  Last 10 training episodes: mean/median reward 4.0/3.0, min/max reward -1.0/13.0
#
# Updates 342, num timesteps 20580, FPS 125
#  Last 10 training episodes: mean/median reward 4.2/3.5, min/max reward -1.0/13.0
#
# Updates 343, num timesteps 20640, FPS 126
#  Last 10 training episodes: mean/median reward 5.2/4.5, min/max reward -1.0/13.0
#
# Updates 344, num timesteps 20700, FPS 126
#  Last 10 training episodes: mean/median reward 6.5/4.5, min/max reward -1.0/18.0
#
# Updates 345, num timesteps 20760, FPS 126
#  Last 10 training episodes: mean/median reward 6.5/4.5, min/max reward -1.0/18.0
#
# Updates 346, num timesteps 20820, FPS 126
#  Last 10 training episodes: mean/median reward 6.6/4.5, min/max reward -1.0/18.0
#
# Updates 347, num timesteps 20880, FPS 127
#  Last 10 training episodes: mean/median reward 6.6/4.5, min/max reward -1.0/18.0
#
# Updates 348, num timesteps 20940, FPS 127
#  Last 10 training episodes: mean/median reward 6.6/4.5, min/max reward -1.0/18.0
#
# Updates 349, num timesteps 21000, FPS 127
#  Last 10 training episodes: mean/median reward 5.4/4.0, min/max reward -1.0/18.0
#
# Updates 350, num timesteps 21060, FPS 127
#  Last 10 training episodes: mean/median reward 5.4/4.0, min/max reward -1.0/18.0
#
#  Evaluation using 10 episodes: mean reward 0.40000
#
# Updates 351, num timesteps 21120, FPS 123
#  Last 10 training episodes: mean/median reward 6.7/5.0, min/max reward 0.0/18.0
#
# Updates 352, num timesteps 21180, FPS 124
#  Last 10 training episodes: mean/median reward 6.7/5.0, min/max reward 0.0/18.0
#
# Updates 353, num timesteps 21240, FPS 124
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 0.0/18.0
#
# Updates 354, num timesteps 21300, FPS 124
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 0.0/18.0
#
# Updates 355, num timesteps 21360, FPS 124
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 0.0/18.0
#
# Updates 356, num timesteps 21420, FPS 125
#  Last 10 training episodes: mean/median reward 8.6/7.0, min/max reward 0.0/18.0
#
# Updates 357, num timesteps 21480, FPS 125
#  Last 10 training episodes: mean/median reward 9.4/10.0, min/max reward 0.0/18.0
#
# Updates 358, num timesteps 21540, FPS 125
#  Last 10 training episodes: mean/median reward 9.4/10.0, min/max reward 0.0/18.0
#
# Updates 359, num timesteps 21600, FPS 126
#  Last 10 training episodes: mean/median reward 9.4/10.0, min/max reward 0.0/18.0
#
# Updates 360, num timesteps 21660, FPS 126
#  Last 10 training episodes: mean/median reward 7.7/6.5, min/max reward 0.0/18.0
#
#  Evaluation using 10 episodes: mean reward 4.00000
#
# Updates 361, num timesteps 21720, FPS 121
#  Last 10 training episodes: mean/median reward 7.6/6.5, min/max reward 0.0/18.0
#
# Updates 362, num timesteps 21780, FPS 122
#  Last 10 training episodes: mean/median reward 7.9/6.5, min/max reward 1.0/18.0
#
# Updates 363, num timesteps 21840, FPS 122
#  Last 10 training episodes: mean/median reward 7.9/6.5, min/max reward 1.0/18.0
#
# Updates 364, num timesteps 21900, FPS 122
#  Last 10 training episodes: mean/median reward 6.8/5.0, min/max reward 1.0/18.0
#
# Updates 365, num timesteps 21960, FPS 122
#  Last 10 training episodes: mean/median reward 5.4/4.5, min/max reward 1.0/13.0
#
# Updates 366, num timesteps 22020, FPS 123
#  Last 10 training episodes: mean/median reward 4.7/3.0, min/max reward 1.0/13.0
#
# Updates 367, num timesteps 22080, FPS 123
#  Last 10 training episodes: mean/median reward 4.7/3.0, min/max reward 1.0/13.0
#
# Updates 368, num timesteps 22140, FPS 123
#  Last 10 training episodes: mean/median reward 4.7/3.0, min/max reward 1.0/13.0
#
# Updates 369, num timesteps 22200, FPS 123
#  Last 10 training episodes: mean/median reward 2.8/3.0, min/max reward 1.0/5.0
#
# Updates 370, num timesteps 22260, FPS 124
# ...
#  Last 10 training episodes: mean/median reward 27.5/21.5, min/max reward 3.0/61.0
#
# Updates 2417, num timesteps 145080, FPS 105
#  Last 10 training episodes: mean/median reward 27.5/21.5, min/max reward 3.0/61.0
# Updates 2418, num timesteps 145140, FPS 105
#  Last 10 training episodes: mean/median reward 27.5/21.5, min/max reward 3.0/61.0
#
# Updates 2419, num timesteps 145200, FPS 105
#  Last 10 training episodes: mean/median reward 27.5/21.5, min/max reward 3.0/61.0
#
# Updates 2420, num timesteps 145260, FPS 105
#  Last 10 training episodes: mean/median reward 26.9/18.5, min/max reward 3.0/61.0
#
#  Evaluation using 10 episodes: mean reward 12.30000
#
# Updates 2421, num timesteps 145320, FPS 105
#  Last 10 training episodes: mean/median reward 26.9/18.5, min/max reward 3.0/61.0
#
# Updates 2422, num timesteps 145380, FPS 105
#  Last 10 training episodes: mean/median reward 26.9/18.5, min/max reward 3.0/61.0
#
# Updates 2423, num timesteps 145440, FPS 105
#  Last 10 training episodes: mean/median reward 26.9/18.5, min/max reward 3.0/61.0
#
# Updates 2424, num timesteps 145500, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2425, num timesteps 145560, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2426, num timesteps 145620, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2427, num timesteps 145680, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2428, num timesteps 145740, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2429, num timesteps 145800, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
# Updates 2430, num timesteps 145860, FPS 105
#  Last 10 training episodes: mean/median reward 21.1/14.0, min/max reward 3.0/56.0
#
#  Evaluation using 10 episodes: mean reward 16.60000
#
# Updates 2431, num timesteps 145920, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/18.5, min/max reward 3.0/56.0
#
# Updates 2432, num timesteps 145980, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/18.5, min/max reward 3.0/56.0
#
# Updates 2433, num timesteps 146040, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/18.5, min/max reward 3.0/56.0
#
# Updates 2434, num timesteps 146100, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/19.0, min/max reward 1.0/56.0
#
# Updates 2435, num timesteps 146160, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/19.0, min/max reward 1.0/56.0
#
# Updates 2436, num timesteps 146220, FPS 104
#  Last 10 training episodes: mean/median reward 23.4/19.0, min/max reward 1.0/56.0
#
# Updates 2437, num timesteps 146280, FPS 104
#  Last 10 training episodes: mean/median reward 22.3/19.0, min/max reward 0.0/56.0
#
# Updates 2438, num timesteps 146340, FPS 104
#  Last 10 training episodes: mean/median reward 22.3/19.0, min/max reward 0.0/56.0
#
# Updates 2439, num timesteps 146400, FPS 104
#  Last 10 training episodes: mean/median reward 22.3/19.0, min/max reward 0.0/56.0
#
# Updates 2440, num timesteps 146460, FPS 104
#  Last 10 training episodes: mean/median reward 20.7/15.5, min/max reward 0.0/56.0
#
#  Evaluation using 10 episodes: mean reward 11.00000
#
# Updates 2441, num timesteps 146520, FPS 104
#  Last 10 training episodes: mean/median reward 20.7/15.5, min/max reward 0.0/56.0
#
# Updates 2442, num timesteps 146580, FPS 104
#  Last 10 training episodes: mean/median reward 20.7/15.5, min/max reward 0.0/56.0
#
# Updates 2443, num timesteps 146640, FPS 104
#  Last 10 training episodes: mean/median reward 20.7/15.5, min/max reward 0.0/56.0
#
# Updates 2444, num timesteps 146700, FPS 104
#  Last 10 training episodes: mean/median reward 15.5/10.5, min/max reward 0.0/38.0
#
# Updates 2445, num timesteps 146760, FPS 104
#  Last 10 training episodes: mean/median reward 15.5/10.5, min/max reward 0.0/38.0
#
# Updates 2446, num timesteps 146820, FPS 104
#  Last 10 training episodes: mean/median reward 18.6/11.0, min/max reward 0.0/46.0
#
# Updates 2447, num timesteps 146880, FPS 104
#  Last 10 training episodes: mean/median reward 18.6/11.0, min/max reward 0.0/46.0
#
# Updates 2448, num timesteps 146940, FPS 104
#  Last 10 training episodes: mean/median reward 18.4/11.0, min/max reward 0.0/46.0
#
# Updates 2449, num timesteps 147000, FPS 104
#  Last 10 training episodes: mean/median reward 18.4/11.0, min/max reward 0.0/46.0
#
# Updates 2450, num timesteps 147060, FPS 104
#  Last 10 training episodes: mean/median reward 18.4/11.0, min/max reward 0.0/46.0
#
#  Evaluation using 10 episodes: mean reward 14.40000
#
# Updates 2451, num timesteps 147120, FPS 104
#  Last 10 training episodes: mean/median reward 14.0/5.0, min/max reward 0.0/46.0
#
# Updates 2452, num timesteps 147180, FPS 104
#  Last 10 training episodes: mean/median reward 17.5/11.0, min/max reward 0.0/46.0
#
# Updates 2453, num timesteps 147240, FPS 104
#  Last 10 training episodes: mean/median reward 17.5/11.0, min/max reward 0.0/46.0
#
# Updates 2454, num timesteps 147300, FPS 104
#  Last 10 training episodes: mean/median reward 13.4/5.0, min/max reward 0.0/46.0
#
# Updates 2455, num timesteps 147360, FPS 104
#  Last 10 training episodes: mean/median reward 13.4/5.0, min/max reward 0.0/46.0
#
# Updates 2456, num timesteps 147420, FPS 104
#  Last 10 training episodes: mean/median reward 13.7/5.0, min/max reward 1.0/46.0
#
# Updates 2457, num timesteps 147480, FPS 104
#  Last 10 training episodes: mean/median reward 13.7/5.0, min/max reward 1.0/46.0
#
# Updates 2458, num timesteps 147540, FPS 104
#  Last 10 training episodes: mean/median reward 13.4/3.5, min/max reward 1.0/46.0
#
# Updates 2459, num timesteps 147600, FPS 104
#  Last 10 training episodes: mean/median reward 10.0/3.5, min/max reward 1.0/36.0
#
# Updates 2460, num timesteps 147660, FPS 104
#  Last 10 training episodes: mean/median reward 10.1/3.5, min/max reward 1.0/36.0
#
#  Evaluation using 10 episodes: mean reward 18.60000
#
# Updates 2461, num timesteps 147720, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2462, num timesteps 147780, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2463, num timesteps 147840, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2464, num timesteps 147900, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2465, num timesteps 147960, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2466, num timesteps 148020, FPS 103
#  Last 10 training episodes: mean/median reward 7.6/3.0, min/max reward 1.0/36.0
#
# Updates 2467, num timesteps 148080, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/3.5, min/max reward 1.0/36.0
#
# Updates 2468, num timesteps 148140, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/3.5, min/max reward 1.0/36.0
#
# Updates 2469, num timesteps 148200, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/3.5, min/max reward 1.0/36.0
#
# Updates 2470, num timesteps 148260, FPS 103
#  Last 10 training episodes: mean/median reward 7.5/3.5, min/max reward 1.0/22.0
#
#  Evaluation using 10 episodes: mean reward 5.20000
#
# Updates 2471, num timesteps 148320, FPS 103
#  Last 10 training episodes: mean/median reward 7.5/3.5, min/max reward 1.0/22.0
#
# Updates 2472, num timesteps 148380, FPS 103
#  Last 10 training episodes: mean/median reward 7.7/3.5, min/max reward 1.0/22.0
#
# Updates 2473, num timesteps 148440, FPS 103
#  Last 10 training episodes: mean/median reward 7.7/3.5, min/max reward 1.0/22.0
#
# Updates 2474, num timesteps 148500, FPS 103
#  Last 10 training episodes: mean/median reward 7.7/3.5, min/max reward 1.0/22.0
#
# Updates 2475, num timesteps 148560, FPS 103
#  Last 10 training episodes: mean/median reward 7.7/3.5, min/max reward 1.0/22.0
#
# Updates 2476, num timesteps 148620, FPS 103
#  Last 10 training episodes: mean/median reward 7.8/4.0, min/max reward 1.0/22.0
#
# Updates 2477, num timesteps 148680, FPS 103
#  Last 10 training episodes: mean/median reward 7.8/4.0, min/max reward 1.0/22.0
#
# Updates 2478, num timesteps 148740, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/8.0, min/max reward 1.0/22.0
#
# Updates 2479, num timesteps 148800, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/8.0, min/max reward 1.0/22.0
# Updates 2480, num timesteps 148860, FPS 103
#  Last 10 training episodes: mean/median reward 8.6/8.0, min/max reward 1.0/22.0
#
#  Evaluation using 10 episodes: mean reward 22.80000
#
# Updates 2481, num timesteps 148920, FPS 102
#  Last 10 training episodes: mean/median reward 8.6/8.0, min/max reward 1.0/22.0
#
# Updates 2482, num timesteps 148980, FPS 102
#  Last 10 training episodes: mean/median reward 10.5/12.0, min/max reward 1.0/22.0
#
# Updates 2483, num timesteps 149040, FPS 103
#  Last 10 training episodes: mean/median reward 10.5/12.0, min/max reward 1.0/22.0
#
# Updates 2484, num timesteps 149100, FPS 103
#  Last 10 training episodes: mean/median reward 10.5/12.0, min/max reward 1.0/22.0
#
# Updates 2485, num timesteps 149160, FPS 103
#  Last 10 training episodes: mean/median reward 10.5/12.0, min/max reward 1.0/22.0
#
# Updates 2486, num timesteps 149220, FPS 103
#  Last 10 training episodes: mean/median reward 9.4/8.0, min/max reward 1.0/22.0
#
# Updates 2487, num timesteps 149280, FPS 103
#  Last 10 training episodes: mean/median reward 9.4/8.0, min/max reward 1.0/22.0
#
# Updates 2488, num timesteps 149340, FPS 103
#  Last 10 training episodes: mean/median reward 9.4/8.0, min/max reward 1.0/22.0
#
# Updates 2489, num timesteps 149400, FPS 103
#  Last 10 training episodes: mean/median reward 9.3/8.0, min/max reward 1.0/22.0
#
# Updates 2490, num timesteps 149460, FPS 103
#  Last 10 training episodes: mean/median reward 9.3/8.0, min/max reward 1.0/22.0
#
#  Evaluation using 10 episodes: mean reward 13.10000
#
# Updates 2491, num timesteps 149520, FPS 102
#  Last 10 training episodes: mean/median reward 9.3/8.0, min/max reward 1.0/22.0
#
# Updates 2492, num timesteps 149580, FPS 102
#  Last 10 training episodes: mean/median reward 16.2/12.0, min/max reward 1.0/70.0
#
# Updates 2493, num timesteps 149640, FPS 102
#  Last 10 training episodes: mean/median reward 15.4/8.0, min/max reward 1.0/70.0
#
# Updates 2494, num timesteps 149700, FPS 102
#  Last 10 training episodes: mean/median reward 16.7/8.0, min/max reward 1.0/70.0
#
# Updates 2495, num timesteps 149760, FPS 102
#  Last 10 training episodes: mean/median reward 16.7/8.0, min/max reward 1.0/70.0
#
# Updates 2496, num timesteps 149820, FPS 102
#  Last 10 training episodes: mean/median reward 16.7/8.0, min/max reward 1.0/70.0
#
# Updates 2497, num timesteps 149880, FPS 102
#  Last 10 training episodes: mean/median reward 16.7/8.0, min/max reward 1.0/70.0
#
# Updates 2498, num timesteps 149940, FPS 102
#  Last 10 training episodes: mean/median reward 19.0/8.0, min/max reward 1.0/70.0
#
# Updates 2499, num timesteps 150000, FPS 102
#  Last 10 training episodes: mean/median reward 19.4/9.5, min/max reward 1.0/70.0
#
# Updates 2500, num timesteps 150060, FPS 102
#  Last 10 training episodes: mean/median reward 19.4/9.5, min/max reward 1.0/70.0
#
#  Evaluation using 10 episodes: mean reward 11.70000
#
# Updates 2501, num timesteps 150120, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2502, num timesteps 150180, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2503, num timesteps 150240, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2504, num timesteps 150300, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2505, num timesteps 150360, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2506, num timesteps 150420, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2507, num timesteps 150480, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2508, num timesteps 150540, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2509, num timesteps 150600, FPS 102
#  Last 10 training episodes: mean/median reward 19.2/9.5, min/max reward 1.0/70.0
#
# Updates 2510, num timesteps 150660, FPS 102
#  Last 10 training episodes: mean/median reward 22.7/20.0, min/max reward 1.0/70.0
#
#  Evaluation using 10 episodes: mean reward 15.30000
#
# Updates 2511, num timesteps 150720, FPS 102
#  Last 10 training episodes: mean/median reward 22.7/20.0, min/max reward 1.0/70.0
#
# Updates 2512, num timesteps 150780, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2513, num timesteps 150840, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2514, num timesteps 150900, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2515, num timesteps 150960, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2516, num timesteps 151020, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2517, num timesteps 151080, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2518, num timesteps 151140, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2519, num timesteps 151200, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2520, num timesteps 151260, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
#  Evaluation using 10 episodes: mean reward 12.00000
#
# Updates 2521, num timesteps 151320, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2522, num timesteps 151380, FPS 102
#  Last 10 training episodes: mean/median reward 24.5/26.0, min/max reward 1.0/70.0
#
# Updates 2523, num timesteps 151440, FPS 102
#  Last 10 training episodes: mean/median reward 26.8/28.5, min/max reward 2.0/70.0
#
# Updates 2524, num timesteps 151500, FPS 102
#  Last 10 training episodes: mean/median reward 26.8/28.5, min/max reward 2.0/70.0
#
# Updates 2525, num timesteps 151560, FPS 102
#  Last 10 training episodes: mean/median reward 22.2/24.0, min/max reward 2.0/38.0
#
# Updates 2526, num timesteps 151620, FPS 102
#  Last 10 training episodes: mean/median reward 27.5/28.5, min/max reward 2.0/57.0
#
# Updates 2527, num timesteps 151680, FPS 102
#  Last 10 training episodes: mean/median reward 27.5/28.5, min/max reward 2.0/57.0
#
# Updates 2528, num timesteps 151740, FPS 102
#  Last 10 training episodes: mean/median reward 27.5/28.5, min/max reward 2.0/57.0
#
# Updates 2529, num timesteps 151800, FPS 102
#  Last 10 training episodes: mean/median reward 27.5/28.5, min/max reward 2.0/57.0
#
# Updates 2530, num timesteps 151860, FPS 102
#  Last 10 training episodes: mean/median reward 24.0/24.0, min/max reward 2.0/57.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d9b9e5dfaa1b> in <module>
#     128             with torch.no_grad():
#     129                 _, action, _, eval_recurrent_hidden_states = actor_critic.act(
# --> 130                     obs, eval_recurrent_hidden_states, eval_masks, deterministic=True)
#     131
#     132             # Obser reward and next obs
#
# ~/code/projects/pytorch-a2c-ppo-acktr/a2c_ppo_acktr/model.py in act(self, inputs, rnn_hxs, masks, deterministic)
#      62
#      63         action_log_probs = dist.log_probs(action)
# ---> 64         dist_entropy = dist.entropy().mean()
#      65
#      66         return value, action, action_log_probs, rnn_hxs
#
# KeyboardInterrupt:

# %%
j

# %%
envs = make_rl_envs(args.env_name, args.num_processes, args.seed,  device)

obs = envs.reset()
rollouts.obs[0].copy_(obs)
rollouts.to(device)

episode_rewards = deque(maxlen=10)

training_stats = {
    'updates': [],
    'num_timesteps': [],
    'mean_reward': [],
    'median_reward': [],
    'min_reward': [],
    'max_reward': []
}

start = time.time()
for j in range(50):
    for step in range(args.num_steps):
        # Sample actions
        with torch.no_grad():
            value, action, action_log_prob, recurrent_hidden_states = actor_critic.act(
                    rollouts.obs[step],
                    rollouts.recurrent_hidden_states[step],
                    rollouts.masks[step])

        # Obser reward and next obs
        obs, reward, done, infos = envs.step(action)

        for info in infos:
            if 'episode' in info.keys():
                episode_rewards.append(info['episode']['r'])

        # If done then clean the history of observations.
        masks = torch.FloatTensor([[0.0] if done_ else [1.0]
                                   for done_ in done])
        rollouts.insert(obs, recurrent_hidden_states, action, action_log_prob, value, reward, masks)
        
#         obs = obs.values().clone()
        obs = torch.FloatTensor(obs.cpu().data).cuda()
        obs.requires_grad = True
        next_value = actor_critic.get_value(obs,
                                    rollouts.recurrent_hidden_states[-1],
                                    rollouts.masks[-1])
        next_value[0, ...].mean().backward()        
        
        im_display = np.concatenate(np.split(obs[0, ...].detach().cpu().numpy().transpose([1, 2, 0]).astype('uint8'), 4, axis=2), axis=1)
        
        print("reward", reward[0])
        print("action", action[0])
        
        clear_output(True)
        plt.figure(figsize=(10, 10))
        plt.subplot(1, 2, 1)
        plt.imshow(im_display, cmap="gray")        
        
        plt.subplot(1, 2, 2)
        plt.imshow(obs.grad[0,...].sum(dim=0).abs().cpu().numpy(), cmap="gray")        
        
        plt.pause(0.05)

# %%
obs

# %%
im_display = np.concatenate(np.split(obs[0, ...].detach().cpu().numpy().transpose([1, 2, 0]).astype('uint8'), 4, axis=2), axis=1)
plt.imshow(im_display)
